# %%
print("Hello Jupyter Notebook 👋")
# Out:
# Hello Jupyter Notebook 👋

# %% [markdown]
# ## Why Jupyter is powerful?
#
# - Code + Notes ek hi jagah
# - Output turant dikhta hai
# - Learning fast ho jati hai

# %% [markdown]
# <details>
# <summary><b>Click to expand: Binary Classification</b></summary>
#
# - Only 2 classes
# - Example: Pass / Fail
# - Output: 0 or 1
#
# </details>

# %% [markdown]
# <span style="color:green">Important Definition</span>

# %% [markdown]
# <span style="color:red">Exam Point 🔥</span>

# %% [markdown]
# <div style="border:2px solid #247026ff; padding:10px; border-radius:8px;">
# <b>NOTE:</b> Jupyter Notebook supports Markdown + HTML
# </div>

# %% [markdown]
# <pre style="background:#f6f8fa; padding:10px;">
# Binary Classification → 2 classes
# Multi-class → more than 2 classes
# </pre>

# %% [markdown]
# ✅ Definition
# ⚠️ Warning
# 🔥 Exam Important
# 💡 Trick
# 📌 Remember

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# <h2 align="center">Classification Types</h2>

# %% [markdown]
# | Type | Classes | Example |
# |----|----|----|
# | Binary | 2 | Pass / Fail |
# | Multi-class | 3+ | Pass / Fail / Maybe |

# %% [markdown]
# <mark>Very Important Line</mark>

# %% [markdown]
# - [x] Binary Classification
# - [ ] Multi-class Classification
# - [ ] Examples

# %% [markdown]
# <span style="font-size:18px">Readable Content</span>

# %% [markdown]
# ![Confusion Matrix](image.png)
#
# *Figure: Confusion Matrix Example*

# %% [markdown]
# > Binary classification means only two possible outcomes.

# %% [markdown]
# >hii

# %% [markdown]
# $$
# Accuracy = \frac{TP + TN}{Total}
# $$

# %% [markdown]
# ## 📚 Contents
# - [Binary Classification](#binary-classification)
# - [Multi-class Classification](#multi-class-classification)
